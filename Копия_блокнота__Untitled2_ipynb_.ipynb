# %% [markdown]
# Загрузка данных и препроцессинг.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import make_pipeline 
# !pip3 install catboost
from catboost import CatBoostRegressor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: catboost in /usr/local/lib/python3.9/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.3.5)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost) (5.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catboost) (3.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost) (1.15.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost) (0.10.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost) (8.2.2)

# %%
from openpyxl import load_workbook
from pathlib import Path
import itertools as it


ws = load_workbook(Path('market-coordinates.xlsx'))['Sheet1']
address_to_id = {}
for i, row in it.islice(enumerate(ws.rows), 1, 1000):
    address_to_id[row[1].value] = int(row[0].value)

# %%
ws = load_workbook(Path('filled-table.xlsx'), read_only=True)['Sheet']

market_address_ids = []
market_visitor_frequencies = []

for i, row in it.islice(enumerate(ws.rows), 229):
    address = ' '.join([str(row[i].value) for i in [4, 3, 2]])
    #print(address)
    market_address_ids.append([row[0].value, address_to_id[address]])
    
    visitors = int(row[14].value)
    try:
        days = int(row[15].value)
    except TypeError:
        days = 30
    market_visitor_frequencies.append(visitors / days)

print(market_address_ids)
print(len(market_address_ids))
market_address_ids = np.array(market_address_ids)
market_visitor_frequencies = np.array(market_visitor_frequencies)
# Out:
# [[1, 1], [214, 137], [237, 118], [255, 193], [253, 191], [23, 23], [96, 87], [107, 96], [151, 122], [292, 226], [2, 2], [6, 6], [10, 10], [26, 26], [195, 104], [208, 162], [125, 107], [308, 233], [152, 123], [157, 128], [162, 133], [244, 182], [185, 108], [200, 154], [205, 159], [247, 185], [307, 232], [77, 74], [213, 167], [174, 143], [261, 150], [279, 213], [286, 220], [310, 235], [317, 242], [145, 119], [199, 119], [264, 119], [379, 119], [42, 42], [73, 71], [225, 176], [226, 176], [329, 249], [330, 250], [436, 309], [90, 84], [91, 84], [92, 84], [93, 84], [171, 140], [178, 79], [354, 78], [361, 84], [100, 91], [184, 149], [312, 237], [318, 243], [358, 149], [30, 30], [52, 52], [113, 100], [54, 54], [59, 59], [159, 130], [164, 135], [390, 285], [394, 289], [44, 44], [68, 68], [268, 202], [291, 225], [103, 93], [105, 94], [123, 105], [180, 145], [192, 118], [319, 93], [453, 105], [40, 40], [56, 56], [252, 190], [340, 260], [381, 276], [388, 283], [169, 138], [266, 200], [267, 201], [282, 216], [296, 95], [297, 229], [459, 109], [460, 109], [469, 111], [470, 111], [155, 126], [241, 179], [337, 257], [338, 258], [351, 270], [405, 270], [215, 168], [333, 253], [449, 317], [450, 318], [138, 111], [384, 279], [391, 286], [191, 117], [201, 155], [236, 117], [352, 271], [431, 304], [471, 117], [474, 117], [9, 9], [37, 37], [70, 69], [250, 188], [5, 5], [12, 12], [45, 45], [76, 73], [348, 268], [272, 206], [284, 218], [435, 308], [136, 115], [182, 147], [363, 115], [372, 275], [377, 115], [22, 22], [101, 91], [203, 157], [287, 221], [288, 222], [290, 224], [300, 152], [301, 152], [452, 231], [8, 8], [60, 60], [99, 90], [207, 161], [98, 89], [137, 116], [349, 269], [7, 7], [61, 61], [118, 102], [58, 58], [67, 67], [380, 67], [224, 97], [229, 99], [230, 101], [362, 114], [463, 151], [466, 114], [27, 27], [43, 43], [269, 203], [276, 210], [426, 302], [440, 312], [49, 49], [149, 120], [331, 251], [402, 297], [427, 303], [3, 3], [84, 80], [111, 98], [64, 64], [104, 94], [168, 137], [221, 174], [277, 211], [285, 219], [4, 4], [36, 36], [72, 70], [245, 183], [256, 194], [336, 256], [382, 277], [48, 48], [254, 192], [396, 291], [82, 78], [38, 38], [117, 102], [258, 196], [309, 234], [270, 204], [283, 217], [34, 34], [322, 102], [332, 252], [345, 265], [346, 266], [355, 148], [364, 115], [365, 85], [366, 232], [374, 148], [375, 112], [385, 280], [386, 281], [389, 284], [395, 290], [397, 292], [403, 298], [404, 299], [412, 300], [413, 230], [418, 83], [420, 85], [422, 85], [428, 137], [429, 137], [433, 306], [442, 314], [443, 315], [456, 108], [457, 150], [475, 118], [369, 273]]
# 229

# %%
main_data = pd.read_csv('./main_data_4.csv')
main_data.head()
# Out:
#    Num         Type Square           Name   Freqs  Period          Building  \
# 0    1  супермаркет    664      Пятерочка  24 945      28  отдельное здание
# 1  237      магазин    137         Другие   7 417      31         жилой дом
# 2  255  супермаркет    845      Пятерочка  57 623      31         жилой дом
# 3  253  супермаркет    203  Ароматный мир  11 760      31         жилой дом
# 4   23      магазин    216         Другие   6 216      33         жилой дом
#
#            FPD
# 0  890,8928571
# 1  239,2580645
# 2  1858,806452
# 3  379,3548387
# 4  188,3636364

# %%
id = []
i, j = 0, 0
while i < 180:
  while j < 229:
    if (main_data['Num'][i] == market_address_ids[j][0]):
      id.append(market_address_ids[j][1])
      break
    j += 1
  i += 1
print(id)
print(len(id))
# Out:
# [1, 118, 193, 191, 23, 87, 122, 226, 2, 6, 10, 26, 162, 107, 233, 128, 133, 182, 108, 154, 159, 185, 232, 74, 167, 143, 213, 220, 235, 242, 119, 42, 71, 176, 249, 250, 309, 84, 84, 84, 140, 79, 91, 237, 243, 30, 100, 54, 59, 130, 135, 289, 44, 68, 202, 94, 105, 145, 118, 105, 40, 56, 190, 260, 283, 138, 200, 201, 216, 229, 109, 111, 111, 126, 257, 258, 270, 270, 168, 253, 318, 111, 117, 155, 304, 117, 9, 37, 69, 188, 5, 12, 73, 268, 206, 218, 308, 147, 275, 115, 91, 157, 221, 222, 224, 152, 152, 8, 60, 90, 161, 89, 116, 269, 7, 61, 58, 67, 67, 101, 114, 151, 114, 27, 43, 203, 210, 312, 120, 251, 297, 303, 3, 80, 98, 94, 137, 211, 219, 36, 70, 183, 194, 256, 277, 48, 192, 291, 38, 102, 196, 234, 204, 217, 34, 252, 265, 266, 148, 85, 232, 112, 280, 281, 284, 290, 292, 298, 299, 300, 230, 83, 85, 85, 137, 306, 315, 150, 118, 273]
# 180

# %%
main_data.insert(1, 'ID', id)
main_data.head()
# Out:
#    Num   ID         Type Square           Name   Freqs  Period  \
# 0    1    1  супермаркет    664      Пятерочка  24 945      28
# 1  237  118      магазин    137         Другие   7 417      31
# 2  255  193  супермаркет    845      Пятерочка  57 623      31
# 3  253  191  супермаркет    203  Ароматный мир  11 760      31
# 4   23   23      магазин    216         Другие   6 216      33
#
#            Building          FPD
# 0  отдельное здание  890,8928571
# 1         жилой дом  239,2580645
# 2         жилой дом  1858,806452
# 3         жилой дом  379,3548387
# 4         жилой дом  188,3636364

# %%
dists = pd.read_csv('./fixed_dist.csv')
dists.head()
# Out:
#    District  Population       Store1       Store2       Store3       Store4  \
# 0         1         646  28,05127469  40,54699233  39,86133175  29,96589644
# 1         2        1562  24,53101023  36,51983572  38,76202941  25,93873983
# 2         3         333  20,18574414  23,90631289  34,28788331  14,26139268
# 3         4        1984  11,75641437  19,64331217  26,31888014   8,41871025
# 4         5        2007  13,89782815  14,75511342  23,47769306  3,444759625
#
#         Store5       Store6       Store7       Store8  ...     Store309  \
# 0  29,08400242  35,20199631  32,16069402  30,76793155  ...  37,15582635
# 1  26,49269262  33,65528252  28,13353742  26,74077495  ...  36,05652401
# 2  19,63058031  23,32137173  17,35291896  15,98574574  ...  32,56289287
# 3  11,22391948  17,20739571  11,30508437  9,912321898  ...   24,1335631
# 4  13,34266433  12,50473867  6,557232515  5,169112684  ...  26,27497689
#
#       Store310     Store311     Store312     Store313     Store314  \
# 0  12,52727614  31,92653471  8,757369081  20,04190608  3,463823592
# 1  18,29523877  37,17121656  10,29062559  23,30607539  8,138245136
# 2  44,25954175  62,11198903  32,39767337   45,3715918  36,53470906
# 3   36,3457885  53,68265926  28,81623836  36,94226203  28,82847446
# 4  38,48720229  55,82407304   33,5081258  39,08367582  31,46759986
#
#       Store315     Store316     Store317     Store318
# 0  15,86386368  31,81204067  22,17310407  22,17310407
# 1  17,32035857  37,58000329  23,72590979  23,72590979
# 2  39,33686203  62,90653109  45,30680316  45,30680316
# 3  35,75542701  54,47720132  36,87747339  36,87747339
# 4  40,44731446  56,61861511  39,01888717  39,01888717
#
# [5 rows x 320 columns]

# %% [markdown]
# Подберем лямбду для каждого из отдельных районов, а в конце попробуем обобщить.

# %%
def to_flt(s):
  if type(s) != type('help'):
    return s
  s = s.replace(' ', '')
  s = s.replace('\xa0', '')
  s = s.split(',')
  s = '.'.join(s)
  return float(s)

def prob_counter(lamb, i, j): # i - номер района, j - номер магазина (порядковый, не ID !!!)
  sum = 0
  for v in range(180):
    sum += to_flt(main_data['Square'][v]) / to_flt((dists[ ('Store' + str(main_data['ID'][v]) )][i - 1]))**lamb
  return (dists['Population'][i - 1]) * to_flt(main_data['Square'][j - 1]) / to_flt((dists[ ('Store' + str(main_data['ID'][j - 1]) )][i - 1]))**lamb / sum

# %%
prob_counter(0.0000001, 11, 1)
# Out:
# 6.710101089597356

# %%
yvals = []
for i in range(180):
  yvals.append(to_flt(main_data['FPD'][i]))
plt.plot(list(i for i in range(180)), yvals)

# %%
main_data.insert(7, 'Huff_predict', list(i for i in range(180)))
main_data.head()
# Out:
#    Num   ID         Type Square           Name   Freqs  Period  Huff_predict  \
# 0    1    1  супермаркет    664      Пятерочка  24 945      28             0
# 1  237  118      магазин    137         Другие   7 417      31             1
# 2  255  193  супермаркет    845      Пятерочка  57 623      31             2
# 3  253  191  супермаркет    203  Ароматный мир  11 760      31             3
# 4   23   23      магазин    216         Другие   6 216      33             4
#
#            Building          FPD
# 0  отдельное здание  890,8928571
# 1         жилой дом  239,2580645
# 2         жилой дом  1858,806452
# 3         жилой дом  379,3548387
# 4         жилой дом  188,3636364

# %%
def huff_predict(i, lamb):
  sum = 0
  for j in range(112):
    sum += prob_counter(lamb, j + 1, i + 1)
  return sum

# %%
cat_cols  = ['Type', 'Name', 'Building']
num_cols = ['Square', 'Huff_predict']
target_col = 'FPD'

# %%
lamb = 0.7
for i in range(180):
  main_data['Huff_predict'][i] = huff_predict(i, lamb)
  main_data['Square'][i] = to_flt(main_data['Square'][i]) 
main_data.head()
# Out:
# <ipython-input-246-e3554bc640de>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_data['Huff_predict'][i] = huff_predict(i, lamb)
# <ipython-input-246-e3554bc640de>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_data['Square'][i] = to_flt(main_data['Square'][i])
#    Num   ID         Type Square           Name   Freqs  Period  Huff_predict  \
# 0    1    1  супермаркет  664.0      Пятерочка  24 945      28          2394
# 1  237  118      магазин  137.0         Другие   7 417      31           593
# 2  255  193  супермаркет  845.0      Пятерочка  57 623      31          3599
# 3  253  191  супермаркет  203.0  Ароматный мир  11 760      31           687
# 4   23   23      магазин  216.0         Другие   6 216      33           681
#
#            Building          FPD
# 0  отдельное здание   890.892857
# 1         жилой дом   239.258064
# 2         жилой дом  1858.806452
# 3         жилой дом   379.354839
# 4         жилой дом   188.363636

# %%
X = main_data.drop(target_col, axis = 1)
X = X.drop('Num', axis = 1)
X = X.drop('ID', axis = 1)
#X = X.drop('Square', axis = 1)
X = X.drop('Freqs', axis = 1)
X = X.drop('Period', axis = 1)
#X = X.drop('Building', axis = 1)
#X = X.drop('Type', axis = 1)
X.head()
# Out:
#           Type Square           Name  Huff_predict          Building
# 0  супермаркет  664.0      Пятерочка          2394  отдельное здание
# 1      магазин  137.0         Другие           593         жилой дом
# 2  супермаркет  845.0      Пятерочка          3599         жилой дом
# 3  супермаркет  203.0  Ароматный мир           687         жилой дом
# 4      магазин  216.0         Другие           681         жилой дом

# %%
Y = main_data[target_col]
for i in range(len(Y)):
  Y[i] = to_flt(Y[i])
Y.head()
# Out:
# <ipython-input-253-4345fa3bf2be>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i] = to_flt(Y[i])
# 0     890.892857
# 1     239.258064
# 2    1858.806452
# 3     379.354839
# 4     188.363636
# Name: FPD, dtype: object

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import StratifiedKFold


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
#создаем пробную модель с default-параметрами
gb_proba = CatBoostRegressor(depth = 15, num_trees = 100, learning_rate = 0.4, eval_metric='MAPE')

gb_proba.fit(X_train, Y_train, cat_features=cat_cols, eval_set=(X_test, Y_test))
# Out:
# 0:	learn: 1.5730128	test: 1.6527224	best: 1.6527224 (0)	total: 383us	remaining: 38ms
# 1:	learn: 1.2768150	test: 1.3742198	best: 1.3742198 (1)	total: 929us	remaining: 45.5ms
# 2:	learn: 1.1821026	test: 1.3013616	best: 1.3013616 (2)	total: 1.5ms	remaining: 48.6ms
# 3:	learn: 1.0266833	test: 1.1570705	best: 1.1570705 (3)	total: 5.38ms	remaining: 129ms
# 4:	learn: 0.9222861	test: 1.0575049	best: 1.0575049 (4)	total: 10.4ms	remaining: 197ms
# 5:	learn: 0.8507182	test: 1.0107897	best: 1.0107897 (5)	total: 12.8ms	remaining: 201ms
# 6:	learn: 0.8035568	test: 0.9971222	best: 0.9971222 (6)	total: 13.4ms	remaining: 178ms
# 7:	learn: 0.7370159	test: 0.9633354	best: 0.9633354 (7)	total: 54.1ms	remaining: 622ms
# 8:	learn: 0.6988833	test: 0.9095746	best: 0.9095746 (8)	total: 74.6ms	remaining: 754ms
# 9:	learn: 0.6760643	test: 0.8693873	best: 0.8693873 (9)	total: 76.6ms	remaining: 689ms
# 10:	learn: 0.6473983	test: 0.8857305	best: 0.8693873 (9)	total: 286ms	remaining: 2.31s
#
# bestTest = 0.771732243
# bestIteration = 40
#
# Shrink model to first 41 iterations.

# %%
Y_predict = gb_proba.predict(X)
Y_pred = gb_proba.predict(X_test)
print(mean_absolute_percentage_error(Y, Y_predict))
print(mean_absolute_percentage_error(Y_test, Y_pred))
# Out:
# 0.5436542841957479
# 0.7717322444723503

# %%
normalization = make_column_transformer((make_pipeline(StandardScaler(), RobustScaler()), num_cols), (OneHotEncoder(), cat_cols))
log_reg = make_pipeline(normalization, LogisticRegression())

cv = StratifiedKFold(n_splits=5)
gscv = GridSearchCV(log_reg, {'logisticregression__C' : [500, 400, 300, 200, 100, 50],
                           'logisticregression__solver' : ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'], 
                    'logisticregression__max_iter' : [100, 200, 500, 1000]}, cv=cv, n_jobs=-1)
gscv.fit(X_train, Y_train)
print(gscv.best_params_)
model = gscv
Y_pred = model.predict(X_test)
print(mean_absolute_percentage_error(Y_test, Y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-0c6e37a2983a> in <module>
#      12                            'logisticregression__solver' : ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
#      13                     'logisticregression__max_iter' : [100, 200, 500, 1000]}, cv=cv, n_jobs=-1)
# ---> 14 gscv.fit(X_train, Y_train)
#      15 print(gscv.best_params_)
#      16 model = gscv
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     831                         **fit_and_score_kwargs,
#     832                     )
# --> 833                     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834                         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835                     )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     350             )
#     351
# --> 352         for train, test in super().split(X, y, groups):
#     353             yield train, test
#     354
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#      83         X, y, groups = indexable(X, y, groups)
#      84         indices = np.arange(_num_samples(X))
# ---> 85         for test_index in self._iter_test_masks(X, y, groups):
#      86             train_index = indices[np.logical_not(test_index)]
#      87             test_index = indices[test_index]
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py in _iter_test_masks(self, X, y, groups)
#     731
#     732     def _iter_test_masks(self, X, y=None, groups=None):
# --> 733         test_folds = self._make_test_folds(X, y)
#     734         for i in range(self.n_splits):
#     735             yield test_folds == i
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_split.py in _make_test_folds(self, X, y)
#     693         min_groups = np.min(y_counts)
#     694         if np.all(self.n_splits > y_counts):
# --> 695             raise ValueError(
#     696                 "n_splits=%d cannot be greater than the"
#     697                 " number of members in each class." % (self.n_splits)
#
# ValueError: n_splits=5 cannot be greater than the number of members in each class.

# %%
class MyLinearRegression:
    def __init__(self, fit_intercept=True):
        self.fit_intercept = fit_intercept

    def fit(self, X, y):
        # Принимает на вход X, y и вычисляет веса по данной выборке
        # Не забудьте про фиктивный признак равный 1
        
        n, k = X.shape
        
        X_train = X
        if self.fit_intercept:
            X_train = np.hstack((X, np.ones((n, 1))))

        self.w = np.linalg.inv(X_train.T @ X_train) @ X_train.T @ y

        return self
        
    def predict(self, X):
        # Принимает на вход X и возвращает ответы модели
        # Не забудьте про фиктивный признак равный 1
        n, k = X.shape
        if self.fit_intercept:
            X_train = np.hstack((X, np.ones((n, 1))))

        y_pred = X_train @ self.w

        return y_pred
    
    def get_weights(self):
        return self.w

# %%
yfreqs = []
lamb = 0.3
for i in range(180):
  sum = 0
  for j in range(112):
    sum += prob_counter(lamb, j + 1, i + 1)
  yfreqs.append(sum)
plt.plot(list(i for i in range(180)), yfreqs)
plt.show()
yvals = np.array(yvals)
yfreqs = np.array(yfreqs)
np.corrcoef(yvals, yfreqs)
# Out:
# array([[1.      , 0.668633],
#        [0.668633, 1.      ]])
